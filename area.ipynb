# %%
import geopandas as gpd
import folium
from folium import Choropleth, Circle, Marker
from folium.plugins import HeatMap, MarkerCluster
import math
import missingno as msno
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from matplotlib import font_manager, rc

font_path = r'C:/Users/user/NanumFontSetup_TTF_ALL/NanumGothic.ttf'
font_name = font_manager.FontProperties(fname=font_path, size=18).get_name()
rc('font',family=font_name)

# %%
seoul_area = gpd.read_file('./data/서울시 행정구역 및 집계구 정보(SHP)/서울시_행정구역_4326.shp',encoding="EUC-KR")
seoul_area
# Out:
#     SIDO_CD SIDO_NM SIGUNGU_CD SIGUNGU_NM   ADM_CD ADM_NM  \
# 0        11   서울특별시      11010        종로구  1101053    사직동
# 1        11   서울특별시      11010        종로구  1101054    삼청동
# 2        11   서울특별시      11010        종로구  1101055    부암동
# 3        11   서울특별시      11010        종로구  1101056    평창동
# 4        11   서울특별시      11010        종로구  1101057    무악동
# ..      ...     ...        ...        ...      ...    ...
# 419      11   서울특별시      11250        강동구  1125070   둔촌1동
# 420      11   서울특별시      11250        강동구  1125071   둔촌2동
# 421      11   서울특별시      11250        강동구  1125072   암사1동
# 422      11   서울특별시      11250        강동구  1125073   천호2동
# 423      11   서울특별시      11250        강동구  1125074     길동
#
#                                               geometry
# 0    POLYGON ((126.97399 37.57823, 126.97400 37.578...
# 1    POLYGON ((126.97714 37.59768, 126.97730 37.597...
# 2    POLYGON ((126.96253 37.60575, 126.96246 37.605...
# ...

# %%
seoul_area.columns
# Out:
# Index(['SIDO_CD', 'SIDO_NM', 'SIGUNGU_CD', 'SIGUNGU_NM', 'ADM_CD', 'ADM_NM',
#        'geometry'],
#       dtype='object')

# %%
# 서울시 중심부의 위도, 경도 입니다.
center = [37.541, 126.986]

# 맵이 center 에 위치하고, zoom 레벨은 11로 시작하는 맵 m을 만듭니다.
m = folium.Map(location=center, zoom_start=10)

# Choropleth 레이어를 만들고, 맵 m에 추가합니다.
folium.Choropleth(
    geo_data=geo_data,
    data=df,
    columns=('동', '인구'),
    key_on='feature.properties.동',
    fill_color='BuPu',
    legend_name='노령 인구수',
).add_to(m)
